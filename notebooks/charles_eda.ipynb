# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = '../data/fridge_284.csv'
data = pd.read_csv(url)

# %%
data.head()
# Out:
#                    timestamp  power
# 0  2020-12-04 00:32:37+00:00   44.0
# 1  2020-12-04 00:32:38+00:00   44.0
# 2  2020-12-04 00:32:39+00:00   44.0
# 3  2020-12-04 00:32:40+00:00   44.0
# 4  2020-12-04 00:32:41+00:00   44.0

# %%
data.shape
# Out:
# (2592000, 2)

# %%
data[:1000].plot()
# Out:
# <AxesSubplot: >

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2592000 entries, 0 to 2591999
# Data columns (total 2 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  datetime64[ns, UTC]
#  1   power      float64
# dtypes: datetime64[ns, UTC](1), float64(1)
# memory usage: 39.6 MB

# %%
sub_data = data[:100000]

plt.figure(figsize=(15,5))
plt.plot(sub_data['timestamp'], sub_data['power'])

# %%
url = '../data/micro_wave_oven_314.csv'
microwave_data = pd.read_csv(url)
microwave_data.shape
# Out:
# (2592001, 2)

# %%
microwave_data.head()
# Out:
#                    timestamp  power
# 0  2021-02-03 15:19:26+00:00    0.0
# 1  2021-02-03 15:19:27+00:00    0.0
# 2  2021-02-03 15:19:28+00:00    0.0
# 3  2021-02-03 15:19:29+00:00    0.0
# 4  2021-02-03 15:19:30+00:00    0.0

# %%
microwave_sub_data = microwave_data[:1000]

plt.figure(figsize=(15,5))
plt.plot(microwave_sub_data['timestamp'], microwave_sub_data['power'])
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7f1d8720bf70> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#     120
#     121
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
# ...
